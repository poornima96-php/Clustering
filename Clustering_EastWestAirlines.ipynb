# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
dataset= pd.read_csv(r'C:\Users\poorn\OneDrive\Documents\ExcelR\Asssignment\Assign_7\EastWestAirlines.csv')
dataset.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# EDA

# %%
dataset.rename(columns={'ID#':'ID', 'Award?':'Award'}, inplace=True)

# %%
dataset.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
dataset.shape
# Out:
# (3999, 12)

# %%
dataset.columns
# Out:
# Index(['ID', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
dataset.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#Outlier detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset.columns
# Out:
# Index(['ID', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=dataset)
# Out:
# <Axes: >

# %%
sns.boxplot(data=np.sqrt(data))
# Out:
# <Axes: >

# %%
dataset.corr()
# Out:
#                          ID   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID                 1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award             -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
# correlation heatmap

f,ax = plt.subplots(figsize=(18,12))
sns.heatmap(dataset.corr(), annot=True, linewidths =.5, fmt ='.1f',ax=ax)
plt.show()

# %% [markdown]
# Hierarchical- clustering

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Normalization function 
standard_scaler = StandardScaler()
std_data = standard_scaler.fit_transform(dataset)
std_data
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
std_data.shape
# Out:
# (3999, 12)

# %%
# Using Minmaxscaler for accuracy result comparison

from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

minmax_df = minmax.fit_transform(dataset)
minmax_df.shape
# Out:
# (3999, 12)

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
# Normalized data frame (considering the numerical part of data)
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(dataset.iloc[:,1:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Create Dendrograms
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(df_norm,'single'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'single')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='single', n_clusters=4)

# %%
# save clusters for chart
y_hc = hc.fit_predict(df_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %%
df_norm['h_clusterid'] = hc.labels_

# %%
df_norm.groupby('h_clusterid').agg(['mean']).reset_index()
# Out:
#   h_clusterid   Balance Qual_miles cc1_miles cc2_miles cc3_miles Bonus_miles  \
#                    mean       mean      mean      mean      mean        mean
# 0           0  0.056938   0.021545  0.415991  0.007776  0.004564    0.109070
# 1           1  0.035081   0.007858  0.176330  0.006950  0.002184    0.038788
# 2           2  0.093917   0.044851  0.000000  0.000000  0.000000    0.272879
# 3           3  0.005019   0.000000  0.000000  0.000000  0.000000    0.760840
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll Award
#          mean              mean            mean              mean  mean
# 0    0.183051          0.027173        0.048401          0.557881   1.0
# 1    0.106314          0.007343        0.012311          0.460411   0.0
# 2    1.000000          1.000000        1.000000          0.165300   1.0
# 3    0.058140          0.020184        0.056604          0.235471   1.0

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(df_norm['h_clusterid'], df_norm['Balance'], c=hc.labels_)

# %% [markdown]
# Kmeans Clustering

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(std_data)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Build Cluster algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(4, random_state=42)
clusters_new.fit(std_data)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
clusters_new.labels_
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
#Assign clusters to the data set
dataset['clusterid_new'] = clusters_new.labels_

# %%
#these are standardized values.
clusters_new.cluster_centers_
# Out:
# array([[ 0.96348204, -0.33447901, -0.04889987, -0.48734503,  0.01619205,
#         -0.06276658, -0.45026351, -0.39262157, -0.18437536, -0.20386635,
#         -0.95068552, -0.32826237],
#        [-0.41557722,  0.53722948,  0.02079723,  1.37989762, -0.08478884,
#          0.18140525,  1.19026584,  0.82327074, -0.06342671, -0.06760719,
#          0.41591883,  0.66642103],
#        [-0.79328273, -0.1648967 , -0.06171985, -0.50524757,  0.0270986 ,
#         -0.05881706, -0.46621457, -0.37541717, -0.1658828 , -0.17656592,
#          0.772364  , -0.24002927],
#        [-0.22708278,  1.20284695,  0.8613124 ,  0.10111012,  0.16228153,
#         -0.06276658,  0.63485991,  1.68030149,  3.607528  ,  3.91562026,
#          0.27255539,  0.93222938]])

# %%
dataset.groupby('clusterid_new').agg(['mean']).reset_index()
# Out:
#   clusterid_new           ID        Balance  Qual_miles cc1_miles cc2_miles  \
#                         mean           mean        mean      mean      mean
# 0             0  3133.055231   39898.197531  106.287199  1.388564  1.016894
# 1             1  1532.492552  127734.216485  160.202582  3.959285  1.001986
# 2             2  1094.120278   56985.831149   96.370085  1.363917  1.018504
# 3             3  1751.262821  194803.871795  810.397436  2.198718  1.038462
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000   6271.906433    7.831709        201.923977        0.600390
# 1  1.047666  45887.323734   19.507448        371.256207        1.117180
# 2  1.000771   5886.720894    7.996916        227.814187        0.703932
# 3  1.000000  32475.410256   27.737179       5510.717949       16.224359
#
#   Days_since_enroll     Award
#                mean      mean
# ...

# %% [markdown]
# DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.8, min_samples=6)
dbscan.fit(std_data)
# Out:
# DBSCAN(eps=0.8, min_samples=6)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([dataset,cl],axis=1)
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...
